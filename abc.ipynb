       0.61705161, 0.61929032, 0.61892903, 0.61942581, 0.61980645,
       0.62145161, 0.62143226, 0.62006452, 0.61991613, 0.62083226,
       0.62188387, 0.62224516, 0.62224516, 0.62369032, 0.62314839,
       0.62303871, 0.62473548, 0.62267097, 0.62297419, 0.62231613,
       0.62374194, 0.62183871, 0.62328387, 0.62225806, 0.62245806,
       0.62173548, 0.62088387, 0.62084516, 0.62307097, 0.62452903,
       0.62285161, 0.62430968, 0.62578065, 0.62684516, 0.62472903,
       0.62623871, 0.62623871, 0.62595484, 0.6247871 , 0.62631613,
       0.62711613, 0.62545161, 0.62723226, 0.62513548, 0.62547742,
       0.62566452, 0.62590968, 0.62703226, 0.62701935, 0.62785806,
       0.62715484, 0.6277871 , 0.62888387, 0.62962581, 0.63093548,
       0.62923871, 0.63103226, 0.63070323, 0.632     , 0.63167097,
       0.62935484, 0.62898065, 0.62949677, 0.62931613, 0.63143871,
       0.63016129, 0.63028387, 0.62945161, 0.62929032, 0.6297871 ,
       0.63088387, 0.6292129 , 0.63070323, 0.62802581, 0.63011613,
       0.62939355, 0.62861935, 0.62792903, 0.62889677, 0.62923226,
       0.62949032, 0.62892903, 0.62847097, 0.63065806, 0.6320129 ,
       0.63096129, 0.63170968, 0.63250323, 0.63153548, 0.63197419,
       0.63234194, 0.6332129 , 0.63294194, 0.6314129 , 0.63389677,
       0.63395484, 0.63481935, 0.63469032, 0.63482581, 0.6347871 ,
       0.6352129 , 0.63463226, 0.63483226, 0.63574839, 0.63655484,
       0.63593548, 0.63605806, 0.63590323, 0.63583226, 0.63594194,
       0.63517419, 0.63389677, 0.63304516, 0.63383226, 0.6317871 ])

# %%
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 10), sharex=True)

# ---- First plot ----
ax1.plot(mean_test_accs_lrdy, c='green', label='lrdy power=0.7')
ax1.plot(mean_test_accs_rand, c='blue', label='rand')

title = 'LRDY and Rand Accuracy to epoch\n'
title += f'[n_genes, int(n_genes / 2), int(n_genes / 4), int(n_genes / 8), n_classes]\n'
title += f'Pre train: batch_size=256, lr=1e-3, epochs=30\n'
# title += f'Actual train: {batch_size=}, {lr=}, {epochs=}\n'
# # title += f'Train: \'{train_file_name}\' x {train_file_name2} with {adata_train.shape[0]} obs\n'
# # title += f'Test: \'{test_file_name}\' x {test_file_name2}  with {adata_test.shape[0]} obs\n'
# title += 'Train wrong labels: 0.05\n'
# title += 'Train X matrix noise: 0\n'
# title += f'{iterations} iterations of the experiment\n'

ax1.set_title(title)
ax1.set_ylabel('Average accuracy')
ax1.grid()
ax1.legend()

# ---- Second plot ----
ax2.plot((mean_test_accs_lrdy - mean_test_accs_rand), c='red', ls='--', label='diff lrdy-rand')
ax2.set_ylabel('Accuracy difference')
ax2.set_xlabel('Epochs')
ax2.grid()
ax2.legend()

plt.tight_layout()
plt.show()
